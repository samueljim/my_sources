# %%
from transformers import pipeline

# %%
pl = pipeline('text-generation', framework='pt')

# %%
text = pl('Pop’s Review Of His First Ever Craft Beer Not Fit For Print', max_length=2000)[0]['generated_text']

print(text)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-14f64c1c89a8> in <module>
# ----> 1 text = pl('Pop’s Review Of His First Ever Craft Beer Not Fit For Print', max_length=2000)[0]['generated_text']
#       2
#       3 print(text)
#
# ~/miniconda3/envs/thalience/lib/python3.8/site-packages/transformers/pipelines.py in __call__(self, return_tensors, return_text, clean_up_tokenization_spaces, prefix, *args, **generate_kwargs)
#     887                 ), "Batch generation is currently not supported. See https://github.com/huggingface/transformers/issues/3021 for more information."
#     888
# --> 889                 output_sequences = self.model.generate(input_ids=input_ids, **generate_kwargs)  # BS x SL
#     890
#     891             result = []
#
# ...
